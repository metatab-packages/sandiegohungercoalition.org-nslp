# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # SDHC NSLP Data
# `sandiegohungercoalition.org-nslp-1.1.1` Last Update: 2021-04-05T20:57:20
#
# _NLSP Data extracted from the SDHC Redshift database_
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [nslp_14_18](notebooks/Combine.ipynb)**.
# * ** [nslp_all_siteid_sponsid](file:data/nslp_all_siteid_sponsid.csv#&encoding=utf8)**.
# * ** [nslp_bfast2_with_id](file:data/nslp_bfast2_with_id.csv#&encoding=ascii)**.
#
# ## References
# ...

# %%
from metapack_build.core import alt_col_name

def re_columnize(df):
    df.columns = [alt_col_name(c) for c in df.columns]
    df = df.rename(columns={'ï_claimdate':'claimdate', 'county_name':'county',
                            'report_date':'fnsreportdate'})
    return df

nslp_frames = [r.dataframe() for r in pkg.references()]

nslp_frames = [re_columnize(f) for f in nslp_frames]

nslp = pd.concat(nslp_frames)

nslp.head().T
# Out:
#                                                                 0  \
# fnsreportdate                                          2014-04-01
# academicyear                                            2013-2014
# programcode                                                  NSLP
# programgroupyear                                             2014
# county                                                  SAN DIEGO
# sponsorname                         SAN DIEGO CENTER FOR CHILDREN
# siteid                                                        NaN
# sitename          JACK & CAROL CLARK ADOLESCENT TREATMENT PROGRAM
# mealtypecode                            NSLP_BREAKFAST_SEVERENEED
# daysservedqty                                                  30
# mlsservedfree                                                 621
# mlsservedredc                                                   0
# mlsservedpaid                                                   0
# ...
